# %% [markdown]
# **QUESTION-1**
#
# **Read the data with pandas and find features and target variables**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
data = pd.read_csv("/content/archive (10).zip")
data
# Out:
#     YearsExperience    Salary
# 0               1.1   39343.0
# 1               1.3   46205.0
# 2               1.5   37731.0
# 3               2.0   43525.0
# 4               2.2   39891.0
# 5               2.9   56642.0
# 6               3.0   60150.0
# 7               3.2   54445.0
# 8               3.2   64445.0
# 9               3.7   57189.0
# 10              3.9   63218.0
# 11              4.0   55794.0
# 12              4.0   56957.0
# 13              4.1   57081.0
# 14              4.5   61111.0
# 15              4.9   67938.0
# 16              5.1   66029.0
# 17              5.3   83088.0
# 18              5.9   81363.0
# 19              6.0   93940.0
# 20              6.8   91738.0
# 21              7.1   98273.0
# 22              7.9  101302.0
# 23              8.2  113812.0
# 24              8.7  109431.0
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# 29             10.5  121872.0

# %%
y=data['Salary']
y
# Out:
# 0      39343.0
# 1      46205.0
# 2      37731.0
# 3      43525.0
# 4      39891.0
# 5      56642.0
# 6      60150.0
# 7      54445.0
# 8      64445.0
# 9      57189.0
# 10     63218.0
# 11     55794.0
# 12     56957.0
# 13     57081.0
# 14     61111.0
# 15     67938.0
# 16     66029.0
# 17     83088.0
# 18     81363.0
# 19     93940.0
# 20     91738.0
# 21     98273.0
# 22    101302.0
# 23    113812.0
# 24    109431.0
# 25    105582.0
# 26    116969.0
# 27    112635.0
# 28    122391.0
# 29    121872.0
# Name: Salary, dtype: float64

# %%
x=data.iloc[0:30,0]
x
# Out:
# 0      1.1
# 1      1.3
# 2      1.5
# 3      2.0
# 4      2.2
# 5      2.9
# 6      3.0
# 7      3.2
# 8      3.2
# 9      3.7
# 10     3.9
# 11     4.0
# 12     4.0
# 13     4.1
# 14     4.5
# 15     4.9
# 16     5.1
# 17     5.3
# 18     5.9
# 19     6.0
# 20     6.8
# 21     7.1
# 22     7.9
# 23     8.2
# 24     8.7
# 25     9.0
# 26     9.5
# 27     9.6
# 28    10.3
# 29    10.5
# Name: YearsExperience, dtype: float64

# %% [markdown]
# **Plot a graph between features and target**

# %%
plt.figure(figsize=(10,8))
plt.scatter(y,x)
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.title('Experience VS Salary')
plt.show()

# %% [markdown]
# **Find Best fit line using linear regression**

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=20, random_state=25)
model = LinearRegression()
x_train = x_train.values.reshape(-1, 1)
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
x_test = x_test.values.reshape(-1, 1)
y_pred = model.predict(x_test)
plt.figure(figsize=(10,8))
plt.scatter(x_test,y_test)
plt.plot(x_test, y_pred, color='red')
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.title('Experience VS Salary')
plt.show()

# %% [markdown]
# **FInd MSE, MAE, for test size (20,25)**

# %%
w0 = 1
w1 = 3
y_pred = w0 + w1*x
y_pred
# Out:
# 0      4.3
# 1      4.9
# 2      5.5
# 3      7.0
# 4      7.6
# 5      9.7
# 6     10.0
# 7     10.6
# 8     10.6
# 9     12.1
# 10    12.7
# 11    13.0
# 12    13.0
# 13    13.3
# 14    14.5
# 15    15.7
# 16    16.3
# 17    16.9
# 18    18.7
# 19    19.0
# 20    21.4
# 21    22.3
# 22    24.7
# 23    25.6
# 24    27.1
# 25    28.0
# 26    29.5
# 27    29.8
# 28    31.9
# 29    32.5
# Name: YearsExperience, dtype: float64

# %%
diff = y-y_pred
print(diff)
print(diff**2)
# Out:
# 0      39338.7
# 1      46200.1
# 2      37725.5
# 3      43518.0
# 4      39883.4
# 5      56632.3
# 6      60140.0
# 7      54434.4
# 8      64434.4
# 9      57176.9
# 10     63205.3
# 11     55781.0
# 12     56944.0
# 13     57067.7
# 14     61096.5
# 15     67922.3
# 16     66012.7
# 17     83071.1
# 18     81344.3
# 19     93921.0
# 20     91716.6
# 21     98250.7
# 22    101277.3
# 23    113786.4
# 24    109403.9
# 25    105554.0
# 26    116939.5
# 27    112605.2
# 28    122359.1
# 29    121839.5
# dtype: float64
# 0     1.547533e+09
# 1     2.134449e+09
# 2     1.423213e+09
# 3     1.893816e+09
# 4     1.590686e+09
# 5     3.207217e+09
# 6     3.616820e+09
# 7     2.963104e+09
# 8     4.151792e+09
# 9     3.269198e+09
# 10    3.994910e+09
# 11    3.111520e+09
# 12    3.242619e+09
# 13    3.256722e+09
# 14    3.732782e+09
# 15    4.613439e+09
# 16    4.357677e+09
# 17    6.900808e+09
# 18    6.616895e+09
# 19    8.821154e+09
# 20    8.411935e+09
# 21    9.653200e+09
# ...

# %% [markdown]
# **Questions 2:**

# %% [markdown]
# **Read the data with pandas and find features and target variables**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
d = pd.read_csv("/content/feature_target_data.csv")
d
# Out:
#    Feature 1  Feature 2  Feature 3  Feature 4  Target (Y)
# 0        1.2        2.3        3.1        4.2        15.6
# 1        2.4        1.9        2.8        3.5        13.1
# 2        3.5        2.7        1.5        2.9        12.4
# 3        4.1        3.0        3.6        4.8        18.2
# 4        1.9        2.8        2.5        3.2        14.1
# 5        3.7        2.5        1.9        4.0        16.0
# 6        2.1        3.2        2.2        4.1        14.5
# 7        3.3        2.4        3.0        4.5        17.3
# 8        2.8        3.1        1.8        3.6        14.9
# 9        4.0        3.3        2.7        4.9        19.2

# %%
tar=d['Feature 4']
tar
x=data.iloc[0:30,0]
x
# Out:
# 0      1.1
# 1      1.3
# 2      1.5
# 3      2.0
# 4      2.2
# 5      2.9
# 6      3.0
# 7      3.2
# 8      3.2
# 9      3.7
# 10     3.9
# 11     4.0
# 12     4.0
# 13     4.1
# 14     4.5
# 15     4.9
# 16     5.1
# 17     5.3
# 18     5.9
# 19     6.0
# 20     6.8
# 21     7.1
# 22     7.9
# 23     8.2
# 24     8.7
# 25     9.0
# 26     9.5
# 27     9.6
# 28    10.3
# 29    10.5
# Name: YearsExperience, dtype: float64

# %% [markdown]
# **Plot a graph between features and target**

# %%
plt.figure(figsize=(10,8))
plt.scatter(fea['Feature 4'],tar)
plt.xlabel('Feature 4')
plt.ylabel('Target')
plt.title('Feature 4 VS Target')
plt.show()

# %% [markdown]
# **Find Best fit line using linear regression.**

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
X = fea[['Feature 4', 'Feature 3']]
model.fit(X, tar)
y_pred = model.predict(X)

# %%
plt.figure(figsize=(10,8))
plt.scatter(fea['Feature 4'],tar)
plt.plot(fea['Feature 4'], y_pred, color='red')
plt.xlabel('Feature 4')
plt.ylabel('Target')
plt.title('Feature 4 VS Target')
plt.show()

# %% [markdown]
# **Fond MSE , MAE for test size (20,30)**

# %%
w0 = 20
w1 = 30
y_pred = w0 + w1*x
y_pred
# Out:
# 0      53.0
# 1      59.0
# 2      65.0
# 3      80.0
# 4      86.0
# 5     107.0
# 6     110.0
# 7     116.0
# 8     116.0
# 9     131.0
# 10    137.0
# 11    140.0
# 12    140.0
# 13    143.0
# 14    155.0
# 15    167.0
# 16    173.0
# 17    179.0
# 18    197.0
# 19    200.0
# 20    224.0
# 21    233.0
# 22    257.0
# 23    266.0
# 24    281.0
# 25    290.0
# 26    305.0
# 27    308.0
# 28    329.0
# 29    335.0
# Name: YearsExperience, dtype: float64

# %%
diff1 = y-y_pred
print(diff1)
print(diff1**2)
# Out:
# 0      39290.0
# 1      46146.0
# 2      37666.0
# 3      43445.0
# 4      39805.0
# 5      56535.0
# 6      60040.0
# 7      54329.0
# 8      64329.0
# 9      57058.0
# 10     63081.0
# 11     55654.0
# 12     56817.0
# 13     56938.0
# 14     60956.0
# 15     67771.0
# 16     65856.0
# 17     82909.0
# 18     81166.0
# 19     93740.0
# 20     91514.0
# 21     98040.0
# 22    101045.0
# 23    113546.0
# 24    109150.0
# 25    105292.0
# 26    116664.0
# 27    112327.0
# 28    122062.0
# 29    121537.0
# dtype: float64
# 0     1.543704e+09
# 1     2.129453e+09
# 2     1.418728e+09
# 3     1.887468e+09
# 4     1.584438e+09
# 5     3.196206e+09
# 6     3.604802e+09
# 7     2.951640e+09
# 8     4.138220e+09
# 9     3.255615e+09
# 10    3.979213e+09
# 11    3.097368e+09
# 12    3.228171e+09
# 13    3.241936e+09
# 14    3.715634e+09
# 15    4.592908e+09
# 16    4.337013e+09
# 17    6.873902e+09
# 18    6.587920e+09
# 19    8.787188e+09
# 20    8.374812e+09
# 21    9.611842e+09
# ...
